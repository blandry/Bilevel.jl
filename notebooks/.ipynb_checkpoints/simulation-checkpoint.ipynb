# %%
using Revise

using RigidBodyDynamics
using RigidBodyDynamics: Bounds

using RigidBodyTreeInspector
using DrakeVisualizer
using Plots

using BilevelTrajOpt
# Out:
# WARNING: Method definition ip_solve(AbstractArray{T, N} where N, Any, Any, Any, Any, Any) in module BilevelTrajOpt at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:60 overwritten at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:59.

# %%
urdf = joinpath("..", "urdf", "ball.urdf")
mechanism = parse_urdf(Float64, urdf)
body = findbody(mechanism, "ball")
basejoint = joint_to_parent(body, mechanism)
floatingjoint = Joint(basejoint.name, frame_before(basejoint), frame_after(basejoint), QuaternionFloating{Float64}())
replace_joint!(mechanism, basejoint, floatingjoint)
position_bounds(floatingjoint) .= Bounds(-100, 100)
velocity_bounds(floatingjoint) .= Bounds(-100, 100)
env = parse_contacts(mechanism, urdf, .5);
x0 = MechanismState(mechanism)
Δt = 0.01;

# %%
q0 = [1., 0., 0., 0., 0., 0., .0]
v0 = [0., 0., 0., .25, 0. , 0.]
N = 5

set_configuration!(x0, q0)
set_velocity!(x0, v0)
setdirty!(x0)

# println("Explicit Contacts")
# traj_exp = BilevelTrajOpt.simulate(x0,env,Δt,N,implicit_contact=false);
println("Implicit Contacts")
traj_imp = BilevelTrajOpt.simulate(x0,env,Δt,N,implicit_contact=true);
# Out:
# Explicit Contacts
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Implicit Contacts
# InterruptException:
#
# Stacktrace:
#  [1] broadcast_t(::Function, ::Type{Any}, ::Tuple{Base.OneTo{Int64},Base.OneTo{Int64}}, ::CartesianRange{CartesianIndex{2}}, ::Array{Any,2}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}) at ./broadcast.jl:264
#  [2] broadcast_c at ./broadcast.jl:321 [inlined]
#  [3] broadcast at ./broadcast.jl:455 [inlined]
#  [4] pos_contact_constraints(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7},7},1}, ::Int64, ::Int64, ::Array{Int64,1}, ::Array{Int64,1}, ::Array{Int64,1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}, ::Array{Any,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:99
#  [5] L(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7},7},1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Float64, ::BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}, ::BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Arr ...
#  [6] (::BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}} ...
#  [7] vector_mode_gradient at /Users/blandry/.julia/v0.6/ForwardDiff/src/gradient.jl:96 [inlined]
#  [8] gradient(::Function, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7},1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Ar ...
#  [9] vector_mode_jacobian(::ForwardDiff.##71#72{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1 ...
#  [10] jacobian(::Function, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7},1}}, ::Val{false}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:17
#  [11] hessian(::Function, ::Array{Float64,1}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{F ...
#  [12] hessian(::Function, ::Array{Float64,1}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},Float64,7,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}},BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##17#18{Array{Float64,1},Array{Float64,1},Float64,BilevelTrajOpt.##49#52{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}},BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{F ...
#  [13] auglag_solve(::Array{Float64,1}, ::Function, ::BilevelTrajOpt.##50#53{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}}, ::BilevelTrajOpt.##51#54{BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}}, ::Int64, ::Int64, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:47
#  [14] #solve_implicit_contact_τ#48(::Bool, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::BilevelTrajOpt.SimData, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{Float64,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:135
#  [15] solve_implicit_contact_τ(::BilevelTrajOpt.SimData, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},2}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{Float64,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:117
#  [16] (::BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:127
#  [17] chunk_mode_jacobian(::BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}}, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}}}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:212
#  [18] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}}}, ::Val{true}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:36
#  [19] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##71#77{BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,7},1}}}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:32 (repeats 2 times)
#  [20] (::BilevelTrajOpt.#eval_jac_g#76{BilevelTrajOpt.SimData,BilevelTrajOpt.#eval_g#72{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}})(::Array{Float64,1}, ::Symbol, ::Array{Int32,1}, ::Array{Int32,1}, ::Array{Float64,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:146
#  [21] eval_jac_g_wrapper(::Int32, ::Ptr{Float64}, ::Int32, ::Int32, ::Int32, ::Ptr{Int32}, ::Ptr{Int32}, ::Ptr{Float64}, ::Ptr{Void}) at /Users/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:143
#  [22] solveProblem(::Ipopt.IpoptProblem) at /Users/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:322
#  [23] #simulate#78(::Bool, ::Function, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1}},2}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:262
#  [24] (::BilevelTrajOpt.#kw##simulate)(::Array{Any,1}, ::BilevelTrajOpt.#simulate, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1}},2}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at ./<missing>:0
#  [25] include_string(::String, ::String) at ./loading.jl:522
#  [26] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/blandry/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [27] (::Compat.#inner#14{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/blandry/.julia/v0.6/Compat/src/Compat.jl:332
#  [28] eventloop(::ZMQ.Socket) at /Users/blandry/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [29] (::IJulia.##13#16)() at ./task.jl:335

# %%
ts = cumsum([Δt for i in 1:N]);
plot(traj_exp[11,:],label="explicit")
plot!(traj_imp[11,:],label="implicit")

# %%
DrakeVisualizer.any_open_windows() || (DrakeVisualizer.new_window(); sleep(1));
geometries = visual_elements(mechanism, URDFVisuals(urdf))
vis = Visualizer(mechanism, geometries);

# %%
traj = traj_imp
qs = [traj[1:num_positions(x0),i] for i in 1:N]
ts = cumsum([Δt for i in 1:N]);
RigidBodyTreeInspector.animate(vis, mechanism, ts, qs; realtimerate = .25);
