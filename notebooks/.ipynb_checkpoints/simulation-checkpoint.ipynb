# %%
using Revise

using RigidBodyDynamics
using RigidBodyDynamics: Bounds

using DrakeVisualizer
using Plots
using RigidBodyTreeInspector

using BilevelTrajOpt
gr(size=(500,500), html_output_format=:png);
# Out:
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/9dd84cf97c4fc16956f39829c81f3b6907c8fc83-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/9dd84cf97c4fc16956f39829c81f3b6907c8fc83-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %%
urdf = joinpath("..", "urdf", "ball.urdf")
mechanism = parse_urdf(Float64, urdf)
body = findbody(mechanism, "ball")
basejoint = joint_to_parent(body, mechanism)
floatingjoint = Joint(basejoint.name, frame_before(basejoint), frame_after(basejoint), QuaternionFloating{Float64}())
replace_joint!(mechanism, basejoint, floatingjoint)
position_bounds(floatingjoint) .= Bounds(-100, 100)
velocity_bounds(floatingjoint) .= Bounds(-100, 100)
env = parse_contacts(mechanism, urdf, .5);
x0 = MechanismState(mechanism)
Δt = 0.005;

# %%
# q0 = [1., 0., 0., 0., 0., 0., 0.025]
q0 = [1., 0., 0., 0., 0., 0., 0.0125]
v0 = [0., 0., 0., .25, 0. , 0.]
N = 10

set_configuration!(x0, q0)
set_velocity!(x0, v0)
setdirty!(x0)

println("Explicit Contacts")
traj_exp = BilevelTrajOpt.simulate(x0,env,Δt,N,implicit_contact=false);
println("Implicit Contacts")
traj_imp = BilevelTrajOpt.simulate(x0,env,Δt,N,implicit_contact=true);
# Out:
# Explicit Contacts
# WARNING: Method definition softmax(Any, Any) in module BilevelTrajOpt at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:2 overwritten at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:7.
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Implicit Contacts
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Solve_Succeeded
# Infeasible_Problem_Detected
# InterruptException:
#
# Stacktrace:
#  [1] _methods_by_ftype(::Any, ::Int64, ::UInt64, ::Array{UInt64,1}, ::Array{UInt64,1}) at ./reflection.jl:521
#  [2] _methods_by_ftype(::Any, ::Int64, ::UInt64) at ./reflection.jl:507
#  [3] _methods(::ANY, ::ANY, ::Int64, ::UInt64) at ./reflection.jl:503
#  [4] return_type(::Any, ::Any) at ./inference.jl:5401
#  [5] broadcast_c at ./broadcast.jl:312 [inlined]
#  [6] broadcast(::Function, ::Array{Any,1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1}) at ./broadcast.jl:455
#  [7] complementarity_contact_constraints(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1}, ::Array{Float64,1}, ::Array{Float64,2}, ::BilevelTrajOpt.SimData) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:80
#  [8] #53 at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:153 [inlined]
#  [9] L(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}}, ::BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:9
#  [10] (::BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1}) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:17
#  [11] vector_mode_gradient at /home/blandry/.julia/v0.6/ForwardDiff/src/gradient.jl:96 [inlined]
#  [12] gradient(::Function, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1}}, ::Val{false}) at /home/blandry/.julia/v0.6/ForwardDiff/src/gradient.jl:17
#  [13] vector_mode_jacobian(::ForwardDiff.##71#72{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}}}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}}) at /home/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:139
#  [14] jacobian(::Function, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}}, ::Val{false}) at /home/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:17
#  [15] hessian(::Function, ::Array{Float64,1}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}}, ::Val{true}) at /home/blandry/.julia/v0.6/ForwardDiff/src/hessian.jl:17
#  [16] hessian(::Function, ::Array{Float64,1}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6,Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},6},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##9#10{Array{Float64,1},Array{Float64,1},Int64,BilevelTrajOpt.##53#56{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,2},Array{Float64,1}},BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}},BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}},Float64},Float64,6},1}}) at /home/blandry/.julia/v0.6/ForwardDiff/src/hessian.jl:15 (repeats 2 times)
#  [17] auglag_solve(::Array{Float64,1}, ::Function, ::BilevelTrajOpt.##54#57{BilevelTrajOpt.SimData,Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1},Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1},Array{Float64,1},Array{Float64,1}}, ::BilevelTrajOpt.##55#58{BilevelTrajOpt.SimData,Array{Float64,2}}, ::Int64, ::Int64, ::Array{Int64,1}, ::Array{Int64,1}, ::Array{Float64,1}) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/bilevel.jl:28
#  [18] #solve_implicit_contact_τ#52(::Bool, ::Array{Int64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Function, ::BilevelTrajOpt.SimData, ::Array{Float64,1}, ::Array{Float64,2}, ::Array{Tuple{RigidBodyDynamics.Spatial.Transform3D{Float64},RigidBodyDynamics.Spatial.Transform3D{Float64}},1}, ::Array{RigidBodyDynamics.Spatial.GeometricJacobian{Array{Float64,2}},1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:166
#  [19] (::BilevelTrajOpt.#eval_g#76{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}})(::Array{Float64,1}, ::Array{Float64,1}) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:122
#  [20] eval_g_wrapper(::Int32, ::Ptr{Float64}, ::Int32, ::Int32, ::Ptr{Float64}, ::Ptr{Void}) at /home/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:116
#  [21] solveProblem(::Ipopt.IpoptProblem) at /home/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:318
#  [22] #simulate#82(::Bool, ::Function, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1}},2}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at /home/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:258
#  [23] (::BilevelTrajOpt.#kw##simulate)(::Array{Any,1}, ::BilevelTrajOpt.#simulate, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1}},2}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at ./<missing>:0
#  [24] include_string(::String, ::String) at ./loading.jl:522
#  [25] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/blandry/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [26] (::Compat.#inner#14{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/blandry/.julia/v0.6/Compat/src/Compat.jl:332
#  [27] eventloop(::ZMQ.Socket) at /home/blandry/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [28] (::IJulia.##13#16)() at ./task.jl:335

# %%
ts = cumsum([Δt for i in 1:N]);
j = 7
plot(traj_exp[j,:],label="explicit")
plot!(traj_imp[j,:],label="implicit")

# %%
DrakeVisualizer.any_open_windows() || (DrakeVisualizer.new_window(); sleep(1));
geometries = visual_elements(mechanism, URDFVisuals(urdf))
vis = Visualizer(mechanism, geometries);

# %%
traj = traj_exp
qs = [traj[1:num_positions(x0),i] for i in 1:N]
ts = cumsum([Δt for i in 1:N]);
RigidBodyTreeInspector.animate(vis, mechanism, ts, qs; realtimerate = .25);
