# %%
using Revise
using BilevelTrajOpt

using RigidBodyDynamics
using Plots
gr(size=(500,500), html_output_format=:png);

# %%
urdf = joinpath("..", "urdf", "ball.urdf")
mechanism = parse_urdf(Float64, urdf)
body = findbody(mechanism, "ball")
basejoint = joint_to_parent(body, mechanism)
floatingjoint = Joint(basejoint.name, frame_before(basejoint), frame_after(basejoint), QuaternionFloating{Float64}())
replace_joint!(mechanism, basejoint, floatingjoint)
position_bounds(floatingjoint) .= RigidBodyDynamics.Bounds(-100, 100)
velocity_bounds(floatingjoint) .= RigidBodyDynamics.Bounds(-100, 100)
μ = 0.5
motion_type = :xyz
point = Point3D(default_frame(findbody(mechanism, "floor")), [0.,0.,0.])
normal = FreeVector3D(default_frame(findbody(mechanism, "floor")), [0.,0.,1.])
hs = HalfSpace(point, normal)
floor = Obstacle(hs, μ, motion_type)
obstacles = [floor]
env = parse_contacts(mechanism, urdf, obstacles)
x0 = MechanismState(mechanism)
Δt = 0.005;

# %%
q0 = [1., 0., 0., 0., 0., 0., 0.005]
v0 = [0., 0., 0., 0.1, 0. , 0.]
N = 5

set_configuration!(x0, q0)
set_velocity!(x0, v0)
setdirty!(x0)

ctrl! = (u,t,x) -> u[:] .= 0.;

# %%
println("Explicit Contacts")
traj_exp = BilevelTrajOpt.simulate_ipopt(x0,env,Δt,N,ctrl!,implicit_contact=false);

# %%
println("Implicit Contacts")
traj_imp = BilevelTrajOpt.simulate_ipopt(x0,env,Δt,N,ctrl!,implicit_contact=true);
# Out:
# Implicit Contacts
# [0.0, 0.0, 0.0, 2.47086, -2.36595e-9, -8.57413]
# [0.0, 0.0, 0.0, 2.47086, -2.36595e-9, -8.57413]
#  55.495273 seconds (69.17 M allocations: 3.192 GiB, 4.11% gc time)
# [0.0, 0.0, 0.0, 2.47086, -2.36595e-9, -8.57413]
# [0.0, 0.0, 0.0, 2.47086, -2.36595e-9, -8.57413]
#   0.325683 seconds (1.26 M allocations: 228.769 MiB, 19.80% gc time)
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# [8.27181e-25, 0.0, 0.0, 7.34201, 7.19646e-6, -16.0993]
# [8.27181e-25, 0.0, 0.0, 7.34201, 7.19646e-6, -16.0993]
#   0.319399 seconds (1.26 M allocations: 228.775 MiB, 18.78% gc time)
# [8.27181e-25, 0.0, 0.0, 8.90404, 6.8948e-6, -18.0758]
# [8.27181e-25, 0.0, 0.0, 8.90404, 6.8948e-6, -18.0758]
#   0.319084 seconds (1.26 M allocations: 228.774 MiB, 18.68% gc time)
# [8.27181e-25, 0.0, 0.0, 4.8982, 6.95414e-6, -9.87666]
# [8.27181e-25, 0.0, 0.0, 4.8982, 6.95414e-6, -9.87666]
#   0.317519 seconds (1.26 M allocations: 228.775 MiB, 16.93% gc time)
# [0.0, 4.33681e-19, 0.0, 4.87213, 0.000400875, -9.79948]
# [0.0, 4.33681e-19, 0.0, 4.87213, 0.000400875, -9.79948]
#   0.314519 seconds (1.26 M allocations: 228.771 MiB, 19.14% gc time)
# [-2.64698e-23, 0.0, 0.0, 4.87173, 0.000401029, -9.79866]
# [-2.64698e-23, 0.0, 0.0, 4.87173, 0.000401029, -9.79866]
#   0.304502 seconds (1.26 M allocations: 228.775 MiB, 20.19% gc time)
# [0.0, 8.67362e-19, 2.11758e-22, 5.54943, 0.00210796, -11.0079]
# [0.0, 8.67362e-19, 2.11758e-22, 5.54943, 0.00210796, -11.0079]
#   0.304938 seconds (1.26 M allocations: 228.776 MiB, 17.60% gc time)
# [2.11758e-22, 0.0, 4.23516e-22, 5.55065, 0.00296944, -11.0005]
# [2.11758e-22, 0.0, 4.23516e-22, 5.55065, 0.00296944, -11.0005]
#   0.298584 seconds (1.26 M allocations: 228.776 MiB, 18.98% gc time)
# [0.0, -8.67362e-19, 0.0, 5.68842, 0.00281188, -11.2086]
# [0.0, -8.67362e-19, 0.0, 5.68842, 0.00281188, -11.2086]
#   0.325846 seconds (1.26 M allocations: 228.771 MiB, 20.67% gc time)
# [8.47033e-22, -8.67362e-19, 0.0, 5.33745, 0.0056697, -10.7246]
# [8.47033e-22, -8.67362e-19, 0.0, 5.33745, 0.0056697, -10.7246]
#   0.316132 seconds (1.26 M allocations: 228.776 MiB, 20.01% gc time)
# [-4.23516e-22, 0.0, -4.23516e-22, 5.2594, 0.005358, -10.5073]
# [-4.23516e-22, 0.0, -4.23516e-22, 5.2594, 0.005358, -10.5073]
#   0.287989 seconds (1.26 M allocations: 228.777 MiB, 20.07% gc time)
# [4.23516e-22, 0.0, 0.0, 5.2844, 0.00515673, -10.558]
# [4.23516e-22, 0.0, 0.0, 5.2844, 0.00515673, -10.558]
#   0.290011 seconds (1.26 M allocations: 228.774 MiB, 18.84% gc time)
# [0.0, 0.0, -4.23516e-22, 5.28502, 0.00514754, -10.5594]
# [0.0, 0.0, -4.23516e-22, 5.28502, 0.00514754, -10.5594]
#   0.321770 seconds (1.26 M allocations: 228.771 MiB, 19.19% gc time)
# [4.23516e-22, 0.0, 0.0, 5.28449, 0.00513701, -10.5589]
# [4.23516e-22, 0.0, 0.0, 5.28449, 0.00513701, -10.5589]
#   0.321128 seconds (1.26 M allocations: 228.774 MiB, 19.04% gc time)
# [1.05879e-22, 0.0, -1.05879e-22, 5.28747, -0.000893001, -10.5755]
# [1.05879e-22, 0.0, -1.05879e-22, 5.28747, -0.000893001, -10.5755]
#   0.354900 seconds (1.26 M allocations: 228.778 MiB, 18.01% gc time)
# [3.30872e-24, 8.67362e-19, 0.0, 5.28751, 5.28927e-5, -10.5753]
# [3.30872e-24, 8.67362e-19, 0.0, 5.28751, 5.28927e-5, -10.5753]
#   0.316626 seconds (1.26 M allocations: 228.776 MiB, 21.12% gc time)
# [-4.1359e-25, 8.67362e-19, -4.1359e-25, 5.28747, -4.04887e-6, -10.575]
# [-4.1359e-25, 8.67362e-19, -4.1359e-25, 5.28747, -4.04887e-6, -10.575]
#   0.324672 seconds (1.26 M allocations: 228.777 MiB, 20.01% gc time)
# [0.0, 0.0, -8.27181e-25, 5.28746, -7.18452e-6, -10.575]
# [0.0, 0.0, -8.27181e-25, 5.28746, -7.18452e-6, -10.575]
#   0.294889 seconds (1.26 M allocations: 228.773 MiB, 20.39% gc time)
# [8.27181e-25, -8.67362e-19, 0.0, 5.28748, -1.13018e-5, -10.5749]
# [8.27181e-25, -8.67362e-19, 0.0, 5.28748, -1.13018e-5, -10.5749]
#   0.291512 seconds (1.26 M allocations: 228.778 MiB, 19.58% gc time)
# [3.30872e-24, 0.0, 0.0, 5.28836, -4.10901e-5, -10.577]
# [3.30872e-24, 0.0, 0.0, 5.28836, -4.10901e-5, -10.577]
#   0.316774 seconds (1.26 M allocations: 228.775 MiB, 20.46% gc time)
# [0.0, 8.67362e-19, 0.0, 5.32537, 0.000100795, -10.6563]
# [0.0, 8.67362e-19, 0.0, 5.32537, 0.000100795, -10.6563]
#   0.325057 seconds (1.26 M allocations: 228.771 MiB, 18.42% gc time)
# [6.61744e-24, 0.0, 0.0, 5.31868, 6.36334e-5, -10.6382]
# [6.61744e-24, 0.0, 0.0, 5.31868, 6.36334e-5, -10.6382]
#   0.300631 seconds (1.26 M allocations: 228.771 MiB, 18.65% gc time)
# [6.61744e-24, 0.0, -6.61744e-24, 5.31822, 5.87508e-5, -10.6373]
# [6.61744e-24, 0.0, -6.61744e-24, 5.31822, 5.87508e-5, -10.6373]
#   0.303793 seconds (1.26 M allocations: 228.777 MiB, 20.13% gc time)
# [6.61744e-24, 8.67362e-19, 0.0, 5.31818, 6.13041e-5, -10.6373]
# [6.61744e-24, 8.67362e-19, 0.0, 5.31818, 6.13041e-5, -10.6373]
#   0.291546 seconds (1.26 M allocations: 228.776 MiB, 19.80% gc time)
# [0.0, 8.67362e-19, -6.61744e-24, 5.31816, 6.09065e-5, -10.6373]
# [0.0, 8.67362e-19, -6.61744e-24, 5.31816, 6.09065e-5, -10.6373]
#   0.289802 seconds (1.26 M allocations: 228.777 MiB, 19.21% gc time)
# [0.0, -8.67362e-19, 0.0, 5.31817, 6.04427e-5, -10.6373]
# [0.0, -8.67362e-19, 0.0, 5.31817, 6.04427e-5, -10.6373]
#   0.277705 seconds (1.26 M allocations: 228.772 MiB, 19.02% gc time)
# [0.0, -8.67362e-19, 6.61744e-24, 5.3181, 5.75837e-5, -10.6371]
# [0.0, -8.67362e-19, 6.61744e-24, 5.3181, 5.75837e-5, -10.6371]
#   0.284253 seconds (1.26 M allocations: 228.777 MiB, 19.83% gc time)
# [0.0, 8.67362e-19, 3.30872e-24, 5.31775, 3.35816e-5, -10.6364]
# [0.0, 8.67362e-19, 3.30872e-24, 5.31775, 3.35816e-5, -10.6364]
#   0.498354 seconds (1.26 M allocations: 228.776 MiB, 53.06% gc time)
# [0.0, -8.67362e-19, 0.0, 5.31765, 2.83747e-5, -10.6365]
# [0.0, -8.67362e-19, 0.0, 5.31765, 2.83747e-5, -10.6365]
#   0.333581 seconds (1.26 M allocations: 228.775 MiB, 17.38% gc time)
# [0.0, 8.67362e-19, 3.30872e-24, 5.318, 4.17948e-5, -10.6371]
# [0.0, 8.67362e-19, 3.30872e-24, 5.318, 4.17948e-5, -10.6371]
#   0.305855 seconds (1.26 M allocations: 228.773 MiB, 18.68% gc time)
# [0.0, 0.0, -2.58494e-26, 5.31821, 2.61696e-7, -10.6364]
# [0.0, 0.0, -2.58494e-26, 5.31821, 2.61696e-7, -10.6364]
#   0.289898 seconds (1.26 M allocations: 228.775 MiB, 19.51% gc time)
# [5.16988e-26, 0.0, 5.16988e-26, 5.31807, 6.94567e-7, -10.6362]
# [5.16988e-26, 0.0, 5.16988e-26, 5.31807, 6.94567e-7, -10.6362]
#   0.293044 seconds (1.26 M allocations: 228.776 MiB, 19.46% gc time)
# [0.0, 0.0, -4.1359e-25, 5.31786, 3.93311e-6, -10.6358]
# [0.0, 0.0, -4.1359e-25, 5.31786, 3.93311e-6, -10.6358]
#   0.325541 seconds (1.26 M allocations: 228.775 MiB, 16.02% gc time)
# [2.06795e-25, 0.0, 4.1359e-25, 5.31784, 3.12567e-6, -10.6358]
# [2.06795e-25, 0.0, 4.1359e-25, 5.31784, 3.12567e-6, -10.6358]
#   0.278082 seconds (1.26 M allocations: 228.773 MiB, 20.19% gc time)
# [0.0, 0.0, 0.0, 5.31783, 2.45748e-6, -10.6357]
# [0.0, 0.0, 0.0, 5.31783, 2.45748e-6, -10.6357]
#   0.282956 seconds (1.26 M allocations: 228.773 MiB, 19.86% gc time)
# [0.0, 0.0, 0.0, 5.31783, 1.42771e-6, -10.6357]
# [0.0, 0.0, 0.0, 5.31783, 1.42771e-6, -10.6357]
#   0.272850 seconds (1.26 M allocations: 228.773 MiB, 18.46% gc time)
# [0.0, 0.0, 0.0, 5.31797, -6.14047e-7, -10.636]
# [0.0, 0.0, 0.0, 5.31797, -6.14047e-7, -10.636]
#   0.276370 seconds (1.26 M allocations: 228.770 MiB, 17.60% gc time)
# [0.0, 0.0, 0.0, 5.31798, -6.08593e-7, -10.636]
# [0.0, 0.0, 0.0, 5.31798, -6.08593e-7, -10.636]
#   0.274206 seconds (1.26 M allocations: 228.770 MiB, 17.17% gc time)
# [0.0, 0.0, 5.16988e-26, 5.31797, -5.94292e-7, -10.636]
# [0.0, 0.0, 5.16988e-26, 5.31797, -5.94292e-7, -10.636]
#   0.275387 seconds (1.26 M allocations: 228.775 MiB, 18.59% gc time)
# [2.06795e-25, 0.0, 0.0, 5.31794, -1.93562e-6, -10.6359]
# [2.06795e-25, 0.0, 0.0, 5.31794, -1.93562e-6, -10.6359]
#   0.273883 seconds (1.26 M allocations: 228.775 MiB, 18.45% gc time)
# [0.0, 0.0, 0.0, 5.31795, -1.87972e-6, -10.6359]
# [0.0, 0.0, 0.0, 5.31795, -1.87972e-6, -10.6359]
#   0.272203 seconds (1.26 M allocations: 228.770 MiB, 16.64% gc time)
# [2.06795e-25, 0.0, -2.06795e-25, 5.31795, -1.98111e-6, -10.6359]
# [2.06795e-25, 0.0, -2.06795e-25, 5.31795, -1.98111e-6, -10.6359]
#   0.282117 seconds (1.26 M allocations: 228.777 MiB, 18.47% gc time)
# [1.03398e-25, 0.0, 0.0, 5.31792, -1.22788e-6, -10.6358]
# [1.03398e-25, 0.0, 0.0, 5.31792, -1.22788e-6, -10.6358]
#   0.274925 seconds (1.26 M allocations: 228.775 MiB, 17.47% gc time)
# [0.0, 0.0, 0.0, 5.31792, -1.05379e-6, -10.6358]
# [0.0, 0.0, 0.0, 5.31792, -1.05379e-6, -10.6358]
#   0.286299 seconds (1.26 M allocations: 228.770 MiB, 19.75% gc time)
# [0.0, 0.0, 0.0, 5.31798, -1.04053e-6, -10.6359]
# [0.0, 0.0, 0.0, 5.31798, -1.04053e-6, -10.6359]
#   0.271665 seconds (1.26 M allocations: 228.770 MiB, 17.45% gc time)
# [5.16988e-26, 0.0, 0.0, 5.31787, -5.81579e-7, -10.6357]
# [5.16988e-26, 0.0, 0.0, 5.31787, -5.81579e-7, -10.6357]
#   0.287506 seconds (1.26 M allocations: 228.775 MiB, 16.69% gc time)
# [0.0, 0.0, 0.0, 5.31789, -4.27829e-7, -10.6358]
# [0.0, 0.0, 0.0, 5.31789, -4.27829e-7, -10.6358]
#   0.357711 seconds (1.26 M allocations: 228.773 MiB, 21.68% gc time)
# [5.16988e-26, 0.0, -5.16988e-26, 5.31788, -4.74121e-7, -10.6357]
# [5.16988e-26, 0.0, -5.16988e-26, 5.31788, -4.74121e-7, -10.6357]
#   0.299878 seconds (1.26 M allocations: 228.774 MiB, 16.34% gc time)
# [5.16988e-26, 0.0, 0.0, 5.31788, -4.75003e-7, -10.6357]
# InterruptException:
#
# Stacktrace:
#  [1] getindex at ./boot.jl:394 [inlined]
#  [2] #8 at /Users/blandry/.julia/dev/BilevelTrajOpt/src/auglag.jl:42 [inlined]
#  [3] chunk_mode_gradient!(::DiffResults.MutableDiffResult{1,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},1}}}, ::getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},8,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51# ...
#  [4] gradient! at /Users/blandry/.julia/packages/ForwardDiff/KHAmA/src/gradient.jl:37 [inlined]
#  [5] InnerGradientForHess at /Users/blandry/.julia/packages/ForwardDiff/KHAmA/src/hessian.jl:50 [inlined]
#  [6] chunk_mode_jacobian!(::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::ForwardDiff.InnerGradientForHess{DiffResults.MutableDiffResult{2,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}}},ForwardDiff.HessianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},8},1},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(Bilevel ...
#  [7] jacobian!(::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::ForwardDiff.InnerGradientForHess{DiffResults.MutableDiffResult{2,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}}},ForwardDiff.HessianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},8},1},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Sy ...
#  [8] hessian!(::DiffResults.MutableDiffResult{2,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}}}, ::Function, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},8},1},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){ge ...
#  [9] hessian!(::DiffResults.MutableDiffResult{2,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}}}, ::Function, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::ForwardDiff.HessianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},8},8},1},Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##8#10")){getfield(BilevelTrajOpt, Symbol("##30#33")),Int64},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){ge ...
#  [10] #auglag_solve#6(::Float64, ::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::getfield(BilevelTrajOpt, Symbol("##30#33")), ::getfield(BilevelTrajOpt, Symbol("##31#34")){BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2},Array{Tuple{Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}}},1},Array{GeometricJacobian{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}, ::getfield(BilevelTrajOpt, Symbol("##32#35")){BilevelTrajOpt.SimData,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2},Array{Float64,1},Array{Float64,1}}) at /Users/blandry/.julia/dev/BilevelTrajOpt/src/auglag.jl:75
#  [11] auglag_solve at /Users/blandry/.julia/dev/BilevelTrajOpt/src/auglag.jl:18 [inlined]
#  [12] #solve_implicit_contact_τ#29(::Bool, ::Function, ::BilevelTrajOpt.SimData, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::Array{Tuple{Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}}},1}, ::Array{GeometricJacobian{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/blandry/.julia/dev/BilevelTrajOpt/src/contact.jl:162
#  [13] solve_implicit_contact_τ(::BilevelTrajOpt.SimData, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::Array{Tuple{Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}},Transform3D{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10}}},1}, ::Array{GeometricJacobian{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/blandry/.julia/dev/BilevelTrajOpt/src/contact.jl:141
#  [14] (::getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}) at /Users/blandry/.julia/dev/BilevelTrajOpt/src/simulation_ipopt.jl:35
#  [15] #51 at /Users/blandry/.julia/dev/BilevelTrajOpt/src/simulation_ipopt.jl:77 [inlined]
#  [16] chunk_mode_jacobian(::getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}}, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}) at /Users/blandry/.julia/packages/ForwardDiff/KHAmA/src/jacobian.jl:229
#  [17] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}, ::Val{true}) at /Users/blandry/.julia/packages/ForwardDiff/KHAmA/src/jacobian.jl:36
#  [18] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("##51#59")){getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}) at /Users/blandry/.julia/packages/ForwardDiff/KHAmA/src/jacobian.jl:32 (repeats 2 times)
#  [19] (::getfield(BilevelTrajOpt, Symbol("#eval_jac_g#58")){BilevelTrajOpt.SimData,getfield(BilevelTrajOpt, Symbol("#eval_g#52")){Array{Float64,1},Array{Float64,1},Array{Float64,1},BilevelTrajOpt.SimData,Bool,Array{Float64,1},Array{Float64,1},Array{Float64,1},LinearAlgebra.Symmetric{Float64,Array{Float64,2}}}})(::Array{Float64,1}, ::Symbol, ::Array{Int32,1}, ::Array{Int32,1}, ::Array{Float64,1}) at ./util.jl:156
#  [20] eval_jac_g_wrapper(::Int32, ::Ptr{Float64}, ::Int32, ::Int32, ::Int32, ::Ptr{Int32}, ::Ptr{Int32}, ::Ptr{Float64}, ::Ptr{Nothing}) at /Users/blandry/.julia/packages/Ipopt/vosfb/src/Ipopt.jl:167
#  [21] solveProblem(::Ipopt.IpoptProblem) at /Users/blandry/.julia/packages/Ipopt/vosfb/src/Ipopt.jl:346
#  [22] #simulate_ipopt#60(::Bool, ::Function, ::MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{Joint{Float64,Fixed{Float64}},1},Array{Joint{Float64,QuaternionFloating{Float64}},1}},2}}, ::Environment, ::Float64, ::Int64, ::getfield(Main, Symbol("##5#6"))) at /Users/blandry/.julia/dev/BilevelTrajOpt/src/simulation_ipopt.jl:161
#  [23] (::getfield(BilevelTrajOpt, Symbol("#kw##simulate_ipopt")))(::NamedTuple{(:implicit_contact,),Tuple{Bool}}, ::typeof(simulate_ipopt), ::MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{Joint{Float64,Fixed{Float64}},1},Array{Joint{Float64,QuaternionFloating{Float64}},1}},2}}, ::Environment, ::Float64, ::Int64, ::Function) at ./none:0
#  [24] top-level scope at In[9]:2

# %%
println("Explicit Contacts")
traj_exp = BilevelTrajOpt.simulate_snopt(x0,env,Δt,N,ctrl!,implicit_contact=false);
# Out:
# Explicit Contacts
#  14.560133 seconds (25.75 M allocations: 1.148 GiB, 5.31% gc time)
#   0.001080 seconds (1.76 k allocations: 277.438 KiB)
#   0.001180 seconds (1.76 k allocations: 277.438 KiB)
#   0.001177 seconds (1.76 k allocations: 277.438 KiB)
#   0.000685 seconds (1.76 k allocations: 277.438 KiB)
#   0.000696 seconds (1.76 k allocations: 277.438 KiB)
# Finished successfully: optimality conditions satisfied
#   0.000633 seconds (1.76 k allocations: 277.438 KiB)
#   0.000953 seconds (1.76 k allocations: 277.438 KiB)
#   0.000972 seconds (1.76 k allocations: 277.438 KiB)
# Finished successfully: optimality conditions satisfied
#   0.000583 seconds (1.76 k allocations: 277.438 KiB)
#   0.000870 seconds (1.76 k allocations: 277.438 KiB)
#   0.000579 seconds (1.76 k allocations: 277.438 KiB)
# Finished successfully: optimality conditions satisfied
#   0.001194 seconds (1.76 k allocations: 277.438 KiB)
#   0.000582 seconds (1.76 k allocations: 277.438 KiB)
#   0.000527 seconds (1.76 k allocations: 277.438 KiB)
# Finished successfully: optimality conditions satisfied
#   0.001050 seconds (1.76 k allocations: 277.438 KiB)
#   0.000582 seconds (1.76 k allocations: 277.438 KiB)
#   0.000997 seconds (1.76 k allocations: 277.438 KiB)
# The problem appears to be infeasible: nonlinear infeasibilities minimized

# %%
println("Implicit Contacts")
traj_imp = BilevelTrajOpt.simulate_snopt(x0,env,Δt,N,ctrl!,implicit_contact=true);
# Out:
# Implicit Contacts
#  31.996530 seconds (38.76 M allocations: 1.818 GiB, 4.12% gc time)
#   0.290721 seconds (1.25 M allocations: 228.728 MiB, 20.75% gc time)
#   0.301983 seconds (1.25 M allocations: 228.729 MiB, 18.73% gc time)
#   0.296013 seconds (1.25 M allocations: 228.729 MiB, 21.28% gc time)
#   0.272496 seconds (1.25 M allocations: 228.729 MiB, 19.74% gc time)
#   0.282442 seconds (1.25 M allocations: 228.729 MiB, 19.80% gc time)
#   0.283211 seconds (1.25 M allocations: 228.729 MiB, 21.07% gc time)
#   0.279848 seconds (1.25 M allocations: 228.729 MiB, 19.20% gc time)
#   0.283512 seconds (1.25 M allocations: 228.729 MiB, 21.04% gc time)
#   0.284387 seconds (1.25 M allocations: 228.729 MiB, 20.15% gc time)
#   0.275007 seconds (1.25 M allocations: 228.729 MiB, 19.21% gc time)
#   0.294560 seconds (1.25 M allocations: 228.729 MiB, 22.06% gc time)
# Finished successfully: optimality conditions satisfied
#   0.277932 seconds (1.25 M allocations: 228.729 MiB, 20.09% gc time)
#   0.288408 seconds (1.25 M allocations: 228.729 MiB, 22.04% gc time)
#   0.288440 seconds (1.25 M allocations: 228.729 MiB, 22.42% gc time)
#   0.289781 seconds (1.25 M allocations: 228.729 MiB, 18.76% gc time)
#   0.288591 seconds (1.25 M allocations: 228.729 MiB, 22.03% gc time)
#   0.292906 seconds (1.25 M allocations: 228.727 MiB, 19.61% gc time)
#   0.319319 seconds (1.25 M allocations: 228.727 MiB, 18.72% gc time)
# Finished successfully: optimality conditions satisfied
#   0.295853 seconds (1.25 M allocations: 228.729 MiB, 21.26% gc time)
#   0.283185 seconds (1.25 M allocations: 228.729 MiB, 19.46% gc time)
#   0.297094 seconds (1.25 M allocations: 228.729 MiB, 20.23% gc time)
#   0.298755 seconds (1.25 M allocations: 228.729 MiB, 18.50% gc time)
#   0.330023 seconds (1.25 M allocations: 228.729 MiB, 17.69% gc time)
#   0.335294 seconds (1.25 M allocations: 228.729 MiB, 19.81% gc time)
#   0.327879 seconds (1.25 M allocations: 228.729 MiB, 19.42% gc time)
#   0.317133 seconds (1.25 M allocations: 228.729 MiB, 23.13% gc time)
#   0.291642 seconds (1.25 M allocations: 228.729 MiB, 20.34% gc time)
#   0.319144 seconds (1.25 M allocations: 228.729 MiB, 18.42% gc time)
#   0.298564 seconds (1.25 M allocations: 228.729 MiB, 23.15% gc time)
#   0.283829 seconds (1.25 M allocations: 228.729 MiB, 19.64% gc time)
#   0.297382 seconds (1.25 M allocations: 228.729 MiB, 20.95% gc time)
#   0.298574 seconds (1.25 M allocations: 228.730 MiB, 21.83% gc time)
#   0.284879 seconds (1.25 M allocations: 228.730 MiB, 18.97% gc time)
#   0.302115 seconds (1.25 M allocations: 228.730 MiB, 21.62% gc time)
# Finished successfully: optimality conditions satisfied
#   0.611348 seconds (1.25 M allocations: 228.729 MiB, 47.11% gc time)
#   0.314532 seconds (1.25 M allocations: 228.729 MiB, 17.35% gc time)
#   0.298000 seconds (1.25 M allocations: 228.729 MiB, 20.01% gc time)
#   0.277606 seconds (1.25 M allocations: 228.729 MiB, 19.50% gc time)
#   0.280520 seconds (1.25 M allocations: 228.729 MiB, 20.14% gc time)
#   0.309898 seconds (1.25 M allocations: 228.729 MiB, 17.96% gc time)
#   0.276213 seconds (1.25 M allocations: 228.729 MiB, 18.59% gc time)
#   0.288054 seconds (1.25 M allocations: 228.730 MiB, 19.29% gc time)
#   0.289085 seconds (1.25 M allocations: 228.730 MiB, 19.33% gc time)
#   0.286134 seconds (1.25 M allocations: 228.729 MiB, 20.20% gc time)
#   0.284723 seconds (1.25 M allocations: 228.729 MiB, 19.52% gc time)
#   0.279938 seconds (1.25 M allocations: 228.729 MiB, 18.86% gc time)
#   0.290218 seconds (1.25 M allocations: 228.729 MiB, 20.41% gc time)
#   0.328274 seconds (1.25 M allocations: 228.729 MiB, 17.77% gc time)
#   0.288355 seconds (1.25 M allocations: 228.729 MiB, 23.31% gc time)
#   0.294544 seconds (1.25 M allocations: 228.729 MiB, 21.10% gc time)
#   0.289116 seconds (1.25 M allocations: 228.729 MiB, 18.21% gc time)
#   0.294869 seconds (1.25 M allocations: 228.730 MiB, 18.90% gc time)
#   0.302110 seconds (1.25 M allocations: 228.730 MiB, 19.41% gc time)
#   0.282095 seconds (1.25 M allocations: 228.730 MiB, 17.92% gc time)
#   0.277583 seconds (1.25 M allocations: 228.730 MiB, 21.37% gc time)
#   0.291666 seconds (1.25 M allocations: 228.730 MiB, 18.31% gc time)
# Finished successfully: optimality conditions satisfied
#   0.290287 seconds (1.25 M allocations: 228.728 MiB, 19.44% gc time)
#   0.318080 seconds (1.25 M allocations: 228.728 MiB, 17.97% gc time)
# The problem appears to be infeasible: nonlinear infeasibilities minimized

# %%
ts = cumsum([Δt for i in 1:N]);
j = 11
plot(traj_exp[j,:],label="explicit")
plot!(traj_imp[j,:],label="implicit")
