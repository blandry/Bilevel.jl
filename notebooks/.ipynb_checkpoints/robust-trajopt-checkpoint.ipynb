# %%
using Revise
using BilevelTrajOpt

using RigidBodyDynamics
using MeshCatMechanisms
using ForwardDiff
using Plots

# %%
urdf = joinpath("..", "urdf", "panda", "panda_arm_plate.urdf")
mechanism = parse_urdf(Float64, urdf)
plate_body = findbody(mechanism, "panda_link8")
plate_frame = default_frame(plate_body)

mvis = MechanismVisualizer(mechanism, URDFVisuals(urdf));

# add frame vis to the plate
# setelement!(mvis, plate_frame);
# Out:
# Error handling websocket connection:
# WebSockets.WebSocketClosedError("ws|server respond to OPCODE_CLOSE 1001:Going Away")┌ Info: Closed (5):  💀    1↑     1↓🔒 3602s 127.0.0.1:8701:8701 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:351

# %%
# IJuliaCell(mvis)
open(mvis)
# Out:
# ┌ Info: Serving MeshCat visualizer at http://127.0.0.1:8702
# └ @ MeshCat /home/blandry/.julia/packages/MeshCat/jt9Xz/src/servers.jl:7
# ┌ Info: Listening on: Sockets.InetAddr{Sockets.IPv4}(ip"127.0.0.1", 0x21fe)
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:301
# Process(`xdg-open http://127.0.0.1:8702`, ProcessExited(0))
# ┌ Info: Accept (0):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# ┌ Info: Accept (1):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# ┌ Info: Accept (2):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# ┌ Info: Accept (3):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# ┌ Info: Accept (4):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# Created new window in existing browser session.
# ┌ Info: Accept (5):  🔗    0↑     0↓    0s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:343
# ┌ Info: Closed (2):  💀    0↑     0↓🔒  16s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (4):  💀    0↑     0↓🔒  16s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (3):  💀    0↑     0↓🔒  16s 127.0.0.1:8702:8702 ≣16
# └ @ HTTP.Servers /home/blandry/.julia/packages/HTTP/YjRCz/src/Servers.jl:351

# %%
widget = manipulate!(mvis)
# Out:
# Widgets.Widget{:rbd_manipulator,Any}(OrderedCollections.OrderedDict{Symbol,Any}(:panda_link0_to_world=>Widget{:rbd_joint,Any}(OrderedCollections.OrderedDict{Symbol,Any}(), Observable{Any} with 1 listeners. Value:
# nothing, nothing, defaultlayout),:panda_joint1=>Widget{:rbd_joint,Any}(OrderedCollections.OrderedDict{Symbol,Any}(:q1=>Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-53e9f747-b6b8-46f2-91fd-2495dbcdeede", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint1.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# [0.0], nothing, ##9#10{Array{Widget{:slider,Float64},1}}(Widgets.Widget{:slider,Float64}[Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-53e9f747-b6b8-46f2-91fd-2495dbcdeede", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint1.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-fffdb318-d236-4d51-a8f6-cf9ef42af7c0", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint2.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# [0.0], nothing, ##9#10{Array{Widget{:slider,Float64},1}}(Widgets.Widget{:slider,Float64}[Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-fffdb318-d236-4d51-a8f6-cf9ef42af7c0", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint2.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-0d84d13d-29c9-4380-8401-e702fbb189ee", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint3.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# [0.0], nothing, ##9#10{Array{Widget{:slider,Float64},1}}(Widgets.Widget{:slider,Float64}[Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-0d84d13d-29c9-4380-8401-e702fbb189ee", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint3.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-2dd8de45-5084-4233-a07d-d973d98ee54e", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint4.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# [0.0], nothing, ##9#10{Array{Widget{:slider,Float64},1}}(Widgets.Widget{:slider,Float64}[Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-2dd8de45-5084-4233-a07d-d973d98ee54e", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint4.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# ...
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-6ab6d731-54f4-4743-9969-01b6649087b9", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint7.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# [0.0], nothing, ##9#10{Array{Widget{:slider,Float64},1}}(Widgets.Widget{:slider,Float64}[Widget{:slider,Float64}(OrderedCollections.OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:index=>Observable{Any} with 2 listeners. Value:
# 315,:formatted_vals=>Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"],:formatted_value=>Observable{String} with 1 listeners. Value:
# "0.0",:value=>Observable{Float64} with 2 listeners. Value:
# 0.0), Observable{Float64} with 2 listeners. Value:
# 0.0, Scope("knockout-component-6ab6d731-54f4-4743-9969-01b6649087b9", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["panda_joint7.q1"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>629,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: index, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: formatted_value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("formatted_vals"=>(Observable{Any} with 1 listeners. Value:
# ["-3.14159", "-3.13159", "-3.12158", "-3.11158", "-3.10157", "-3.09157", "-3.08156", "-3.07156", "-3.06155", "-3.05155"  …  "3.05155", "3.06155", "3.07156", "3.08156", "3.09157", "3.10157", "3.11158", "3.12158", "3.13159", "3.14159"], nothing),"changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"formatted_value"=>(Observable{String} with 1 listeners. Value:
# "0.0", nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 315, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/blandry/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/blandry/.julia/packages/InteractBase/3SqBl/src/../assets/style.css"], Dict{Any,Any}("formatted_vals"=>Any[JSString("(function (val){return (val!=this.model[\"formatted_vals\"]()) ? (this.valueFromJulia[\"formatted_vals\"]=true, this.model[\"formatted_vals\"](val)) : undefined})")],"_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"formatted_vals\\\":[\\\"-3.14159\\\",\\\"-3.13159\\\",\\\"-3.12158\\\",\\\"-3.11158\\\",\\\"-3.10157\\\",\\\"-3.09157\\\",\\\"-3.08156\\\",\\\"-3.07156\\\",\\\"-3.06155\\\",\\\"-3.05155\\\",\\\"-3.04154\\\",\\\"-3.03154\\\",\\\"-3.02153\\\",\\\"-3.01153\\\",\\\"-3.00152\\\",\\\"-2.99152\\\",\\\"-2.98151\\\",\\\"-2.97151\\\",\\\"-2.9615\\\",\\\"-2.9515\\\",\\\"-2.94149\\\",\\\"-2.93149\\\",\\\"-2.92148\\\",\\\"-2.91148\\\",\\\"-2.90147\\\",\\\"-2.89147\\\",\\\"-2.88146\\\",\\\"-2.87146\\\",\\\"-2.86145\\\",\\\"-2.85145\\\",\\\"-2.84144\\\",\\\"-2.83144\\\",\\\"-2.82143\\\",\\\"-2.81143\\\",\\\"-2.80142\\\",\\\"-2.79142\\\",\\\"-2.78141\\\",\\\"-2.7714\\\",\\\"-2.7614\\\",\\\"-2.75139\\\",\\\"-2.74139\\\",\\\"-2.73138\\\",\\\"-2.72138\\\",\\\"-2.71137\\\",\\\"-2.70137\\\",\\\"-2.69136\\\",\\\"-2.68136\\\",\\\"-2.67135\\\",\\\"-2.66135\\\",\\\"-2.65134\\\",\\\"-2.64134\\\",\\\"-2.63133\\\",\\\"-2.62133\\\",\\\"-2.61132\\\",\\\"-2.60132\\\",\\\"-2.59131\\\",\\\"-2.58131\\\",\\\"-2.5713\\\",\\\"-2.5613\\\",\\\"-2.55129\\\",\\\"-2.54129\\\",\\\"-2.53128\\\",\\\"-2.52128\\\",\\\"-2.51127\\\",\\\"-2.50127\\\",\\\"-2.49126\\\",\\\"-2.48126\\\",\\\"-2.47125\\\",\\\"-2.46125\\\",\\\"-2.45124\\\",\\\"-2.44124\\\",\\\"-2.43123\\\",\\\"-2.42123\\\",\\\"-2.41122\\\",\\\"-2.40122\\\",\\\"-2.39121\\\",\\\"-2.38121\\\",\\\"-2.3712\\\",\\\"-2.3612\\\",\\\"-2.35119\\\",\\\"-2.34119\\\",\\\"-2.33118\\\",\\\"-2.32118\\\",\\\"-2.31117\\\",\\\"-2.30117\\\",\\\"-2.29116\\\",\\\"-2.28116\\\",\\\"-2.27115\\\",\\\"-2.26115\\\",\\\"-2.25114\\\",\\\"-2.24114\\\",\\\"-2.23113\\\",\\\"-2.22113\\\",\\\"-2.21112\\\",\\\"-2.20112\\\",\\\"-2.19111\\\",\\\"-2.18111\\\",\\\"-2.1711\\\",\\\"-2.1611\\\",\\\"-2.15109\\\",\\\"-2.14109\\\",\\\"-2.13108\\\",\\\"-2.12108\\\",\\\"-2.11107\\\",\\\"-2.10107\\\",\\\"-2.09106\\\",\\\"-2.08106\\\",\\\"-2.07105\\\",\\\"-2.06104\\\",\\\"-2.05104\\\",\\\"-2.04103\\\",\\\"-2.03103\\\",\\\"-2.02102\\\",\\\"-2.01102\\\",\\\"-2.00101\\\",\\\"-1.99101\\\",\\\"-1.981\\\",\\\"-1.971\\\",\\\"-1.96099\\\",\\\"-1.95099\\\",\\\"-1.94098\\\",\\\"-1.93098\\\",\\\"-1.92097\\\",\\\"-1.91097\\\",\\\"-1.90096\\\",\\\"-1.89096\\\",\\\"-1.88095\\\",\\\"-1.87095\\\",\\\"-1.86094\\\",\\\"-1.85094\\\",\\\"-1.84093\\\",\\\"-1.83093\\\",\\\"-1.82092\\\",\\\"-1.81092\\\",\\\"-1.80091\\\",\\\"-1.79091\\\",\\\"-1.7809\\\",\\\"-1.7709\\\",\\\"-1.76089\\\",\\\"-1.75089\\\",\\\"-1.74088\\\",\\\"-1.73088 ...
# nothing, nothing, defaultlayout)]))

# %%
# traj opt without robustness

env = parse_contacts(mechanism, urdf, [])
x0 = MechanismState(mechanism)
Δt = 0.05
N = 10
traj_data = get_traj_data(mechanism,env,Δt,N,false)

x_start = zeros(traj_data.num_q+traj_data.num_v)
x_goal = zeros(traj_data.num_q+traj_data.num_v)

# 1
# x_start[2] = -pi/2
# x_start[6] = pi/2
# x_goal[2] = pi/2
# x_goal[5] = -pi
# x_goal[6] = pi/2

# 2
# x_start[6] = pi
# x_goal[4] = pi/2
# x_goal[6] = pi/2

# 3
x_start[1] = 0
x_start[2] = pi/4
x_start[3] = pi
x_start[4] = -3*pi/4
x_start[6] = -pi
x_goal[1] = -pi
x_goal[2] = -pi/4
x_goal[3] = pi
x_goal[4] = -pi/4
x_goal[6] = -pi

add_state_eq!(traj_data, xi -> xi - x_start, 1)
add_state_eq!(traj_data, xi -> xi - x_goal, N)

for i = 2:N-1
   add_fn_obj!(traj_data, qi -> (qi - x_start[1:traj_data.num_q])'*(qi - x_start[1:traj_data.num_q]),i)
end

# THE TRAJOPT CODE ALSO MINIMIZES CONTROL INPUT

traj = BilevelTrajOpt.trajopt_snopt(traj_data)

traj_t = vcat(0.,cumsum([Δt for i in 1:N-1]));
traj_q = [traj[1:num_positions(mechanism),i] for i in 1:N]
setanimation!(mvis, traj_t, traj_q)
# Out:
# Finished successfully: optimality conditions satisfied

# %%
setanimation!(mvis, traj_t, traj_q)

# %%
# robust version adds a "worst case scenario" computation for "wind gust" on the plate

world_frame = root_frame(mechanism)
function c_wind(q::AbstractArray{T}) where T
    state = MechanismState{T}(mechanism)
    set_configuration!(state, q)
    trans = relative_transform(state, plate_frame, world_frame)
    pn = (trans.mat * [0.,0.,1.,0.])[1:3]
    
    fw = w -> 100. * pn'*w
    hw = w -> [0.]
    gw = w -> vcat(w'*w - 1., w[3]*w[3] - 0.01)
    w0 = zeros(3)
    λ0 = zeros(1)
    μ0 = zeros(2)
    
    wsol,λsol,μsol = auglag_solve(w0,λ0,μ0,fw,hw,gw,in_place=false)

    fw(wsol)^2
end

# verifying the inner optimization
# q = configuration(mvis.state)
# display(c_wind(q))
# ForwardDiff.gradient(c_wind,q)
# for i = 1:N
#     q = traj_robust_q[i]
#     q = traj_q[i]
#     display(c_wind(q))
# end

env = parse_contacts(mechanism, urdf, [])
x0 = MechanismState(mechanism)
Δt = 0.05
N = 10
traj_data = get_traj_data(mechanism,env,Δt,N,false)

x_start = zeros(traj_data.num_q+traj_data.num_v)
x_goal = zeros(traj_data.num_q+traj_data.num_v)

# 1
# x_start[2] = -pi/2
# x_start[6] = pi/2
# x_goal[2] = pi/2
# x_goal[5] = -pi
# x_goal[6] = pi/2

# 2
# x_start[6] = pi
# x_goal[4] = pi/2
# x_goal[6] = pi/2

# 3
x_start[1] = 0
x_start[2] = pi/4
x_start[3] = pi
x_start[4] = -3*pi/4
x_start[6] = -pi
x_goal[1] = -pi
x_goal[2] = -pi/4
x_goal[3] = pi
x_goal[4] = -pi/4
x_goal[6] = -pi

add_state_eq!(traj_data, xi -> xi - x_start, 1)
add_state_eq!(traj_data, xi -> xi - x_goal, N)

for i = 2:N-1
    add_fn_obj!(traj_data, c_wind, i)
end

for i = 2:N-1
   add_fn_obj!(traj_data, qi -> (qi - x_start[1:traj_data.num_q])'*(qi - x_start[1:traj_data.num_q]),i)
end

# THE TRAJOPT CODE ALSO MINIMIZES CONTROL INPUT

traj_robust = BilevelTrajOpt.trajopt_snopt(traj_data)

traj_robust_t = vcat(0.,cumsum([Δt for i in 1:N-1]));
traj_robust_q = [traj_robust[1:num_positions(mechanism),i] for i in 1:N]
setanimation!(mvis, traj_robust_t, traj_robust_q)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] _collect(::Type{Joint{Float64,JT} where JT<:JointType{Float64}}, ::Base.Iterators.Flatten{Tuple{Array{Joint{Float64,JT} where JT<:JointType{Float64},1},Array{Joint{Float64,JT} where JT<:JointType{Float64},1}}}, ::Base.SizeUnknown) at ./iterators.jl:903
#  [2] collect at ./array.jl:518 [inlined]
#  [3] RigidBodyDynamics.Graphs.TreePath(::RigidBody{Float64}, ::RigidBody{Float64}, ::RigidBodyDynamics.Graphs.SpanningTree{RigidBody{Float64},Joint{Float64,JT} where JT<:JointType{Float64}}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/graphs/tree_path.jl:59
#  [4] path at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism.jl:86 [inlined]
#  [5] #43 at ./none:0 [inlined]
#  [6] iterate at ./generator.jl:47 [inlined]
#  [7] RigidBodyDynamics.CustomCollections.IndexDict{JointID,Base.OneTo{JointID},Bool}(::Base.Generator{Array{Joint{Float64,JT} where JT<:JointType{Float64},1},getfield(RigidBodyDynamics, Symbol("##43#50")){Joint{Float64,Revolute{Float64}},Mechanism{Float64}}}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/custom_collections.jl:199
#  [8] (::getfield(RigidBodyDynamics, Symbol("##44#51")){getfield(RigidBodyDynamics, Symbol("##42#49")){Mechanism{Float64}}})(::Joint{Float64,Revolute{Float64}}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism_state.jl:94
#  [9] iterate at ./generator.jl:47 [inlined]
#  [10] RigidBodyDynamics.CustomCollections.IndexDict{JointID,Base.OneTo{JointID},RigidBodyDynamics.CustomCollections.IndexDict{JointID,Base.OneTo{JointID},Bool}}(::Base.Generator{Array{Joint{Float64,JT} where JT<:JointType{Float64},1},getfield(RigidBodyDynamics, Symbol("##44#51")){getfield(RigidBodyDynamics, Symbol("##42#49")){Mechanism{Float64}}}}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/custom_collections.jl:199
#  [11] MechanismState{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},Float64,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},TypeSortedCollections.TypeSortedCollection{Tuple{Array{Joint{Float64,Fixed{Float64}},1},Array{Joint{Float64,Revolute{Float64}},1}},2}}(::Mechanism{Float64}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism_state.jl:96
#  [12] MechanismState{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},Float64,ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},JointCollection} where JointCollection(::Mechanism{Float64}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism_state.jl:163
#  [13] Type at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism_state.jl:168 [inlined]
#  [14] MechanismState{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},M,C,JointCollection} where JointCollection where C where M(::Mechanism{Float64}) at /home/blandry/.julia/packages/RigidBodyDynamics/uyInU/src/mechanism_state.jl:175
#  [15] (::getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}) at /home/blandry/.julia/dev/BilevelTrajOpt/src/trajopt_snopt.jl:46
#  [16] (::getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}) at /home/blandry/.julia/dev/BilevelTrajOpt/src/trajopt_snopt.jl:118
#  [17] chunk_mode_jacobian(::getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}}) at /home/blandry/.julia/packages/ForwardDiff/okZnq/src/jacobian.jl:222
#  [18] jacobian(::Function, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}}, ::Val{true}) at /home/blandry/.julia/packages/ForwardDiff/okZnq/src/jacobian.jl:19
#  [19] jacobian(::Function, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12,Array{ForwardDiff.Dual{ForwardDiff.Tag{getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},Float64},Float64,12},1}}) at /home/blandry/.julia/packages/ForwardDiff/okZnq/src/jacobian.jl:15 (repeats 2 times)
#  [20] (::getfield(BilevelTrajOpt, Symbol("#update_fn#76")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},getfield(BilevelTrajOpt, Symbol("#eval_f#75")){BilevelTrajOpt.TrajData,UnitRange{Int64}}})(::Array{Float64,1}) at /home/blandry/.julia/dev/BilevelTrajOpt/src/trajopt_snopt.jl:174
#  [21] objcon_wrapper(::Ptr{Int64}, ::Int64, ::Ptr{Float64}, ::Int64, ::Int64, ::Ptr{Float64}, ::Int64, ::Int64, ::Ptr{Float64}, ::Ptr{Int8}, ::Int64, ::Ptr{Int64}, ::Int64, ::Ptr{Float64}, ::Int64) at /home/blandry/.julia/dev/BilevelTrajOpt/src/snopt.jl:65
#  [22] #snopt#18(::String, ::String, ::Nothing, ::Nothing, ::Function, ::getfield(BilevelTrajOpt, Symbol("#update_fn#76")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_con#74")){BilevelTrajOpt.TrajData,getfield(BilevelTrajOpt, Symbol("#eval_dyn#72")){BilevelTrajOpt.TrajData,UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64},UnitRange{Int64}}},getfield(BilevelTrajOpt, Symbol("#eval_f#75")){BilevelTrajOpt.TrajData,UnitRange{Int64}}}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Dict{String,Any}) at /home/blandry/.julia/dev/BilevelTrajOpt/src/snopt.jl:335
#  [23] snopt(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Dict{String,Any}) at /home/blandry/.julia/dev/BilevelTrajOpt/src/snopt.jl:133
#  [24] trajopt_snopt(::BilevelTrajOpt.TrajData) at /home/blandry/.julia/dev/BilevelTrajOpt/src/trajopt_snopt.jl:205
#  [25] top-level scope at In[50]:75

# %%
setanimation!(mvis, traj_robust_t, traj_robust_q)

# %%
# compute the disturbance along each trajectory

# with our solver
function compute_dist(q::AbstractArray{T}) where T
    state = MechanismState{T}(mechanism)
    set_configuration!(state, q)
    trans = relative_transform(state, plate_frame, world_frame)
    pn = (trans.mat * [0.,0.,1.,0.])[1:3]
    
    fw = w -> 100. * pn'*w
    hw = w -> [0.]
    gw = w -> vcat(w'*w - 1., w[3]*w[3] - 0.01)
    w0 = zeros(3)
    λ0 = zeros(1)
    μ0 = zeros(2)
    
    wsol,λsol,μsol = auglag_solve(w0,λ0,μ0,fw,hw,gw,in_place=false)
    fw(wsol)^2
end

traj_dist = zeros(N)
traj_robust_dist = zeros(N)
for i = 1:N
    traj_dist[i] = compute_dist(traj_q[i])
    traj_robust_dist[i] = compute_dist(traj_robust_q[i])
end

# %%
gr(size=(800,500), html_output_format=:png, seriescolor=:magma);
plot(traj_t,traj_dist,label="without bilevel objective",seriescolor=:darkslateblue)
plot!(traj_robust_t,traj_robust_dist,label="with bilevel objective",
    seriescolor=:forestgreen,xlabel="time",ylabel="worst case disturbance")

# %%
# with snopt directly

# with our solver
function compute_dist_snopt(q::AbstractArray{T}) where T
    state = MechanismState{T}(mechanism)
    set_configuration!(state, q)
    trans = relative_transform(state, plate_frame, world_frame)
    pn = (trans.mat * [0.,0.,1.,0.])[1:3]
    
    fw = w -> 100. * pn'*w
    gw = w -> vcat(w'*w - 1., w[3]*w[3] - 0.01)
    function snopt_fn(w)
        J = fw(w)
        gJ = ForwardDiff.gradient(fw,w)
        
        c = gw(w)
        gc = ForwardDiff.jacobian(gw,w)
    
        fail = false
    
        J, c, gJ, gc, fail
    end
    
    w0 = zeros(3)
    lb = -1e19*ones(3)
    ub = 1e19*ones(3)
    options = Dict{String, Any}()
    options["Derivative option"] = 1
    options["Verify level"] = -1
    options["Major optimality tolerance"] = 1e-6
    wsol, fsol, info = snopt(snopt_fn, w0, lb, ub, options)
#     display(info)

    fw(wsol)^2
end

traj_dist_snopt = zeros(N)
traj_robust_dist_snopt = zeros(N)
for i = 1:N
    traj_dist_snopt[i] = compute_dist_snopt(traj_q[i])
    traj_robust_dist_snopt[i] = compute_dist_snopt(traj_robust_q[i])
end

# %%
gr(size=(800,500), html_output_format=:png, seriescolor=:magma);
plot(traj_t,traj_dist_snopt,label="without bilevel objective",seriescolor=:darkslateblue)
plot!(traj_robust_t,traj_robust_dist_snopt,label="with bilevel objective",
    seriescolor=:forestgreen,xlabel="time",ylabel="worst case disturbance")
