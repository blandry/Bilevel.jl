# %%
using Revise
using MeshCat
using RigidBodyDynamics
using RigidBodyDynamics: Bounds
using MeshCatMechanisms
using BilevelTrajOpt

# %%
vis = Visualizer()
open(vis)
# Out:
# MeshCatMechanisms.MechanismVisualizer{RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},2}},MeshCat.Visualizer}(MechanismState{Float64, Float64, Float64, …}(…), MeshCat Visualizer with path /meshcat, 10)

# %%
urdf = joinpath("..", "urdf", "panda", "panda_arm_box.urdf")
mechanism = parse_urdf(Float64, urdf)
box = findbody(mechanism, "box")
basejoint = joint_to_parent(box, mechanism)
floatingjoint = Joint(basejoint.name, frame_before(basejoint), frame_after(basejoint), QuaternionFloating{Float64}())
replace_joint!(mechanism, basejoint, floatingjoint)
position_bounds(floatingjoint) .= Bounds(-100, 100)
velocity_bounds(floatingjoint) .= Bounds(-100, 100)
mvis = MechanismVisualizer(mechanism, URDFVisuals(urdf), vis);

# %%
function make_end_effector_controller(state::MechanismState,
                                      end_effector::RigidBody,
                                      end_effector_point::Point3D,
                                      desired_point::Point3D)
    
    mechanism = state.mechanism
    v̇ = similar(velocity(state))
    
    joint_path = path(mechanism, root_body(mechanism), end_effector) # from root to end effector
    Jp = point_jacobian(state, joint_path, transform(state, end_effector_point, root_frame(mechanism)))
        
    function controller!(τ, t, state)
        ef_point_in_world = transform_to_root(state, end_effector) * end_effector_point
        point_jacobian!(Jp, state, joint_path, ef_point_in_world)
        des_point_in_world = transform(state, desired_point, root_frame(mechanism))
        Kp = 10.
        Kd = 5.
        Δp = des_point_in_world - ef_point_in_world
        v̇ .= Kp * Array(Jp)' * Δp.v .- Kd .* velocity(state)
        τ .= inverse_dynamics(state, v̇)
    end
end

desired_point_v = [1., 0., .25]
end_effector = findbody(mechanism, "panda_link8")
end_effector_point = Point3D(default_frame(end_effector), [0.,0.,0.])
desired_point = Point3D(root_frame(mechanism), desired_point_v)
point_ctrl! = make_end_effector_controller(state, end_effector, end_effector_point, desired_point)
# Out:
# Unable to determine to what body after_panda_joint8 is attached
#
# Stacktrace:
#  [1] body_fixed_frame_to_body(::RigidBodyDynamics.Mechanism{Float64}, ::RigidBodyDynamics.Spatial.CartesianFrame3D) at /Users/blandry/.julia/v0.6/RigidBodyDynamics/src/mechanism.jl:160
#  [2] transform_to_root(::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},3}}, ::RigidBodyDynamics.Spatial.CartesianFrame3D) at /Users/blandry/.julia/v0.6/RigidBodyDynamics/src/mechanism_state.jl:906
#  [3] relative_transform(::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},3}}, ::RigidBodyDynamics.Spatial.CartesianFrame3D, ::RigidBodyDynamics.Spatial.CartesianFrame3D) at /Users/blandry/.julia/v0.6/RigidBodyDynamics/src/mechanism_state.jl:962
#  [4] transform at /Users/blandry/.julia/v0.6/RigidBodyDynamics/src/mechanism_state.jl:992 [inlined]
#  [5] make_end_effector_controller(::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},3}}, ::RigidBodyDynamics.RigidBody{Float64}, ::RigidBodyDynamics.Spatial.Point3D{Array{Float64,1}}, ::RigidBodyDynamics.Spatial.Point3D{Array{Float64,1}}) at ./In[75]:10
#  [6] include_string(::String, ::String) at ./loading.jl:522
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/blandry/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [8] (::Compat.#inner#14{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/blandry/.julia/v0.6/Compat/src/Compat.jl:332
#  [9] eventloop(::ZMQ.Socket) at /Users/blandry/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [10] (::IJulia.##13#16)() at ./task.jl:335

# %%
state = MechanismState(mechanism)
# q0 = [1.,0.,0.,0.,0.,0.,0.,-0.00159265,
#       0.858407,0.0184073,-1.89159,0.0884073,
#       -1.94159,0.138407]
q0 = [-0.00159265,
      0.858407,0.0184073,-1.89159,0.0884073,
      -1.94159,0.138407]
set_configuration!(state, q0)
t, q, v = simulate(state, 1.0);

# %%
N = 200
x0 = MechanismState(mechanism)
Δt = 0.005
env = parse_contacts(mechanism, urdf, .5)
traj_exp = BilevelTrajOpt.simulate(x0,env,Δt,N,implicit_contact=false);
traj = traj_exp
q = [traj[1:num_positions(x0),i] for i in 1:N]
t = cumsum([Δt for i in 1:N]);
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] _methods_by_ftype(::Any, ::Int64, ::UInt64, ::Array{UInt64,1}, ::Array{UInt64,1}) at ./reflection.jl:521
#  [2] _methods_by_ftype(::Any, ::Int64, ::UInt64) at ./reflection.jl:507
#  [3] _methods(::ANY, ::ANY, ::Int64, ::UInt64) at ./reflection.jl:503
#  [4] return_type(::Any, ::Any) at ./inference.jl:5401
#  [5] broadcast_c at ./broadcast.jl:312 [inlined]
#  [6] broadcast(::Function, ::Array{Any,1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}) at ./broadcast.jl:455
#  [7] pos_contact_constraints(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},2}, ::BilevelTrajOpt.SimData) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/contact.jl:138
#  [8] (::BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}, ::Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:67
#  [9] chunk_mode_jacobian(::BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}}, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:229
#  [10] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}, ::Val{true}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:36
#  [11] jacobian(::Function, ::Array{Float64,1}, ::Array{Float64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10,Tuple{Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1},Array{ForwardDiff.Dual{ForwardDiff.Tag{BilevelTrajOpt.##69#75{BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}},Float64},Float64,10},1}}}) at /Users/blandry/.julia/v0.6/ForwardDiff/src/jacobian.jl:32 (repeats 2 times)
#  [12] (::BilevelTrajOpt.#eval_jac_g#74{BilevelTrajOpt.SimData,BilevelTrajOpt.#eval_g#70{BilevelTrajOpt.SimData,Array{Float64,1},Array{Float64,1},Array{Float64,1},Symmetric{Float64,Array{Float64,2}}}})(::Array{Float64,1}, ::Symbol, ::Array{Int32,1}, ::Array{Int32,1}, ::Array{Float64,1}) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:82
#  [13] eval_jac_g_wrapper(::Int32, ::Ptr{Float64}, ::Int32, ::Int32, ::Int32, ::Ptr{Int32}, ::Ptr{Int32}, ::Ptr{Float64}, ::Ptr{Void}) at /Users/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:143
#  [14] solveProblem(::Ipopt.IpoptProblem) at /Users/blandry/.julia/v0.6/Ipopt/src/Ipopt.jl:322
#  [15] #simulate#86(::Bool, ::Function, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},3}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at /Users/blandry/.julia/v0.6/BilevelTrajOpt/src/simulation.jl:261
#  [16] (::BilevelTrajOpt.#kw##simulate)(::Array{Any,1}, ::BilevelTrajOpt.#simulate, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.QuaternionFloating{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Revolute{Float64}},1}},3}}, ::BilevelTrajOpt.Environment{Float64}, ::Float64, ::Int64) at ./<missing>:0
#  [17] include_string(::String, ::String) at ./loading.jl:522
#  [18] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/blandry/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [19] (::Compat.#inner#14{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /Users/blandry/.julia/v0.6/Compat/src/Compat.jl:332
#  [20] eventloop(::ZMQ.Socket) at /Users/blandry/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##13#16)() at ./task.jl:335

# %%
setanimation!(mvis, t, q)
# Out:
# true

# %%
widget = manipulate!(mvis)
# Out:
# (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#   (div
#     Observables.Observable{Any}("ob_54", nothing, Any[Observables.g]))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.rw"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.rx"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.ry"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.rz"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.x"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.y"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "floor_to_box.z"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=100.0 min=-100.0 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div
#     Observables.Observable{Any}("ob_79", nothing, Any[Observables.g]))
#   (div
#     Observables.Observable{Any}("ob_80", nothing, Any[Observables.g]))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint1.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint2.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint3.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint4.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint5.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint6.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#     (div { className="field" }
#             (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#         (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#           (label { className="interact " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#             "panda_joint7.q1"))
#         (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#           (input { max=3.138407346410207 min=-3.141592653589793 attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}")) step=0.01 className="slider slider is-fullwidth" style=Dict{Any,Any}() }))
#         (div { attributes=Dict("style"=>"width:18%") }
#           (p { attributes=Dict("data-bind"=>"text: displayedvalue") })))))
#   (div
#     Observables.Observable{Any}("ob_123", nothing, Any[Observables.g])))
